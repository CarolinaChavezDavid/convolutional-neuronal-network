# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import tensorflow_datasets as tfds
import keras
from keras_hub.models import MobileNetV5Backbone
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import tensorflow_datasets as tfds
#       5 import keras
# ----> 6 from keras_hub.models import MobileNetV5Backbone
#
# ModuleNotFoundError: No module named 'keras_hub'
